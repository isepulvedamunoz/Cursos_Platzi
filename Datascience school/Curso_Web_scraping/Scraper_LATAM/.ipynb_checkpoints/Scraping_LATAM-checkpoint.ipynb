# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.latamairlines.com/cl/es/ofertas-vuelos?dataFlight=%7B%22tripTypeSelected%22%3A%7B%22label%22%3A%22Ida+y+Vuelta%22%2C%22value%22%3A%22RT%22%7D%2C%22cabinSelected%22%3A%7B%22label%22%3A%22Economy%22%2C%22value%22%3A%22Economy%22%7D%2C%22passengerSelected%22%3A%7B%22adultQuantity%22%3A1%2C%22childrenQuantity%22%3A0%2C%22infantQuantity%22%3A0%7D%2C%22originSelected%22%3A%7B%22id%22%3A%22SCL_CL_AIRPORT%22%2C%22name%22%3A%22Comodoro+Arturo+Merino+Ben%C3%ADtez+Int.%22%2C%22city%22%3A%22Santiago+de+Chile%22%2C%22country%22%3A%22Chile%22%2C%22iata%22%3A%22SCL%22%2C%22latitude%22%3A-33.393001556396484%2C%22longitude%22%3A-70.78579711914062%2C%22timezone%22%3A-4%2C%22tz%22%3A%22America%2FSantiago%22%2C%22type%22%3A%22AIRPORT%22%2C%22countryAlpha2%22%3A%22CL%22%2C%22airportIataCode%22%3A%22SCL%22%7D%2C%22destinationSelected%22%3A%7B%22id%22%3A%22LSC_CL_AIRPORT%22%2C%22name%22%3A%22La+Florida%22%2C%22city%22%3A%22La+Serena%22%2C%22country%22%3A%22Chile%22%2C%22iata%22%3A%22LSC%22%2C%22latitude%22%3A-29.916201%2C%22longitude%22%3A-71.199501%2C%22timezone%22%3A-4%2C%22tz%22%3A%22America%2FSantiago%22%2C%22type%22%3A%22AIRPORT%22%2C%22countryAlpha2%22%3A%22CL%22%2C%22airportIataCode%22%3A%22LSC%22%7D%2C%22dateGoSelected%22%3A%222021-01-04T20%3A00%3A00.000Z%22%2C%22dateReturnSelected%22%3A%222021-01-08T20%3A00%3A00.000Z%22%2C%22redemption%22%3Afalse%7D'

# %%
r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
s = BeautifulSoup(r.text, 'lxml')

# %%
print(s.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <link href="https://s.latamairlines.com/images/seo/favicon.ico" rel="shortcut icon"/>
#   <link href="https://s.latamairlines.com/images/seo/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="https://s.latamairlines.com/images/seo/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://s.latamairlines.com/images/seo/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link color="#1b0088" href="https://s.latamairlines.com/images/seo/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="#ffffff" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>
#   <meta charset="utf-8"/>
#   <title>
#    Selección de vuelos | Compra | LATAM Airlines
#   </title>
#   <meta content="noindex,nofollow" name="robots"/>
# ...

# %%
from selenium import webdriver

# %%
options = webdriver.ChromeOptions()
options.add_argument('--incognito')
driver = webdriver.Chrome(executable_path='C:/Users/Naxo/Desktop/Platzi/Datascience school/Curso_Web_scraping/chromedriver.exe', options=options)

# %%
driver.get(url)

# %%
vuelos = driver.find_elements_by_xpath('//li[@class="sc-fHSTwm danPdA"]')

# %%
vuelos
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2f634f521d4e5f6b09d9d81be9fe1e7b", element="64e91a0a-eeb7-4f9f-a021-c1c890c8034b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2f634f521d4e5f6b09d9d81be9fe1e7b", element="b531d94f-2b3f-4962-8326-33b8247d86ec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2f634f521d4e5f6b09d9d81be9fe1e7b", element="5a7f1363-3da7-4ec0-a018-dac236c25e71")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2f634f521d4e5f6b09d9d81be9fe1e7b", element="c8822b0a-df69-4431-8616-de5f202686ed")>]

# %%
vuelo = vuelos[0]
vuelo
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2f634f521d4e5f6b09d9d81be9fe1e7b", element="64e91a0a-eeb7-4f9f-a021-c1c890c8034b")>

# %%
vuelo.find_element_by_xpath('.//span[@class="sc-lnmtFM ewiHQE"]')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2f634f521d4e5f6b09d9d81be9fe1e7b", element="f5085eab-42c2-4e1a-92a8-4cb3508dd457")>

# %%
driver.close()
